# %% [markdown]
# # Проект по теме "Автоматизация".
#
# ## 1. Краткое описание задачи
#
# Задача: выгрузить данные из базы данных PostgreSQL при помощи Jupyter Notebook, сохранить ее на локальный компьютер, затем с локального компьютера сформировать дашборд в Tableau Public согласно техническому заданию, оформить презентацию в формате pdf.
#
# Техническое задание по оформлению дашборда:

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)

# %%
#!pip install psycopg2

# %% [markdown]
# Создадим подключение к БД:

# %%
# импортируем библиотеки
import pandas as pd
from sqlalchemy import create_engine

db_config = {'user': 'praktikum_student', # имя пользователя
            'pwd': 'Sdf4$2;d-d30pp', # пароль
            'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
            'port': 6432, # порт подключения
            'db': 'data-analyst-zen-project-db'} # название базы данных

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
                                                db_config['pwd'],
                                                db_config['host'],
                                                db_config['port'],
                                                db_config['db'])

engine = create_engine(connection_string)

# %% [markdown]
# Сформируем запрос SQL:

# %%
query = '''
            SELECT *  FROM dash_visits
        '''

# %% [markdown]
# Сохраним датасет в переменной:

# %%
log_df = pd.io.sql.read_sql(query, con = engine)

# %% [markdown]
# Выведем первые 10 строк на экран:

# %%
log_df.head(10)
# Out:
#    record_id item_topic source_topic age_segment                  dt  visits
# 0    1040597     Деньги         Авто       18-25 2019-09-24 18:32:00       3
# 1    1040598     Деньги         Авто       18-25 2019-09-24 18:35:00       1
# 2    1040599     Деньги         Авто       18-25 2019-09-24 18:54:00       4
# 3    1040600     Деньги         Авто       18-25 2019-09-24 18:55:00      17
# 4    1040601     Деньги         Авто       18-25 2019-09-24 18:56:00      27
# 5    1040602     Деньги         Авто       18-25 2019-09-24 18:57:00      22
# 6    1040603     Деньги         Авто       18-25 2019-09-24 18:58:00      24
# 7    1040604     Деньги         Авто       18-25 2019-09-24 18:59:00      20
# 8    1040605     Деньги         Авто       18-25 2019-09-24 19:00:00       5
# 9    1040606     Деньги         Авто       26-30 2019-09-24 18:29:00       1

# %%
#display(log_df['dt'].min(),'-',log_df['dt'].max())

# %% [markdown]
# Сохраним результат - датафрейм на локальном компьютере:

# %%
log_df.to_csv('dash_visits.csv', index=False)

# %% [markdown]
# По итогу работы сформирован дашборд в Tableau Public.
#
# Ссылка на дашборд: https://public.tableau.com/app/profile/pavel4328/viz/DashboardYandex_Zen_16611047471710/Dashboard1

# %% [markdown]
# По итогу оформления дашборда сформирована презентация.
#
# Ссылка на презентацию: https://disk.yandex.ru/i/0XEVUGG-eI1wtQ

# %% [markdown]
# Спасибо за внимание!
